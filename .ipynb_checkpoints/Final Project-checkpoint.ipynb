# %% [markdown]
# # Data Input

# %%
import pandas as pd
import numpy as np
from python_speech_features import mfcc
from python_speech_features import logfbank
import os
import scipy.io.wavfile as wav
from sklearn.decomposition import PCA

actors = [f for f in os.listdir("./voice") if os.path.isdir(os.path.join("./voice",f))]
minase = [ f for f in os.listdir("./voice/minase") ]
matsuoka = [ f for f in os.listdir("./voice/matsuoka") ]
takahashi = [ f for f in os.listdir("./voice/takahashi") ]
kobayashi = [ f for f in os.listdir("./voice/kobayashi") ]

df = pd.DataFrame(columns=["role","actor"])
for i in minase:
    df = df.append({'role':i,'actor':"minase"},ignore_index=True)
for i in matsuoka:
    df = df.append({'role':i,'actor':"matsuoka"},ignore_index=True)
for i in takahashi:
    df = df.append({'role':i,'actor':"takahashi"},ignore_index=True)
for i in kobayashi:
    df = df.append({'role':i,'actor':"kobayashi"},ignore_index=True)
    
x = df['role']
y = df['actor']

trans_x = []
trans_pca = []
# rate,data = wav.read("./voice/minase/hestia_1.wav")
# t = mfcc(signal=data,samplerate=rate,winlen=0.5,winstep=0.1,nfft=22050,numcep=1)

for i,j in enumerate(x):
    #print(y.iloc[i])
    rate,data = wav.read("./voice/"+y.iloc[i]+"/"+j)
    t = mfcc(signal=data,samplerate=rate,winlen=0.5,winstep=data.shape[0]/rate/5,nfft=data.shape[0],numcep=1)
#     pca = PCA(n_components=1)
#     g = pca.fit_transform(t)
#     g = np.append([],g)
#     trans_pca.append(g)
    print(t.shape,j)
    t=np.append([],t)
    trans_x.append(t)
trans_x=np.asarray(trans_x)
print("done!")
# Out:
# (11, 1) hestia_1.wav
# (11, 1) hestia_10.wav
# (11, 1) hestia_2.wav
# (11, 1) hestia_3.wav
# (11, 1) hestia_4.wav
# (11, 1) hestia_5.wav
# (11, 1) hestia_6.wav
# (11, 1) hestia_7.wav
# (11, 1) hestia_8.wav
# (11, 1) hestia_9.wav
# (11, 1) Rem_1.wav
# (11, 1) Rem_10.wav
# (11, 1) Rem_2.wav
# (11, 1) Rem_3.wav
# (11, 1) Rem_4.wav
# (11, 1) Rem_5.wav
# (11, 1) Rem_6.wav
# (11, 1) Rem_7.wav
# (11, 1) Rem_8.wav
# (11, 1) Rem_9.wav
# (11, 1) bell_1.wav
# (11, 1) bell_10.wav
# (11, 1) bell_2.wav
# (11, 1) bell_3.wav
# (11, 1) bell_4.wav
# (11, 1) bell_5.wav
# (11, 1) bell_6.wav
# (11, 1) bell_7.wav
# (11, 1) bell_8.wav
# (11, 1) bell_9.wav
# (11, 1) xiao_1.wav
# (11, 1) xiao_10.wav
# (11, 1) xiao_2.wav
# (11, 1) xiao_3.wav
# (11, 1) xiao_4.wav
# (11, 1) xiao_5.wav
# (11, 1) xiao_6.wav
# (11, 1) xiao_7.wav
# (11, 1) xiao_8.wav
# (11, 1) xiao_9.wav
# (10, 1) Emilia_1.1.wav
# (10, 1) Emilia_1.2.wav
# (11, 1) Emilia_1.wav
# (11, 1) Emilia_10.wav
# (10, 1) Emilia_2.1.wav
# (11, 1) Emilia_2.2.wav
# (11, 1) Emilia_2.wav
# (11, 1) Emilia_3.1.wav
# (11, 1) Emilia_3.2.wav
# (11, 1) Emilia_3.wav
# (11, 1) Emilia_4.1.wav
# (11, 1) Emilia_4.2.wav
# (11, 1) Emilia_4.wav
# (11, 1) Emilia_5(0).wav
# (11, 1) Emilia_5(1).wav
# (11, 1) Emilia_5.wav
# (11, 1) Emilia_6(0).wav
# (11, 1) Emilia_6(1).wav
# (11, 1) Emilia_6.wav
# (11, 1) Emilia_7(0).wav
# (11, 1) Emilia_7(1).wav
# (11, 1) Emilia_7.wav
# (11, 1) Emilia_8(0).wav
# (11, 1) Emilia_8(1).wav
# (11, 1) Emilia_8.wav
# (11, 1) Emilia_9(0).wav
# (11, 1) Emilia_9(1).wav
# (11, 1) Emilia_9.wav
# (11, 1) hutao_1.wav
# (11, 1) hutao_10.wav
# (11, 1) hutao_2.wav
# (11, 1) hutao_3.wav
# (11, 1) hutao_4.wav
# (11, 1) hutao_5.wav
# (11, 1) hutao_6.wav
# (11, 1) hutao_7.wav
# (11, 1) hutao_8.wav
# (11, 1) hutao_9.wav
# (11, 1) senku_1.wav
# (11, 1) senku_10.wav
# (11, 1) senku_2.wav
# (11, 1) senku_3.wav
# (11, 1) senku_4.wav
# (11, 1) senku_5.wav
# (11, 1) senku_6.wav
# (11, 1) senku_7.wav
# (11, 1) senku_8.wav
# (11, 1) senku_9.wav
# (11, 1) Subaru_1.wav
# (11, 1) Subaru_10.wav
# (11, 1) Subaru_2.wav
# (11, 1) Subaru_3.wav
# (11, 1) Subaru_4.wav
# (11, 1) Subaru_5.wav
# (11, 1) Subaru_6.wav
# (11, 1) Subaru_7.wav
# (11, 1) Subaru_8.wav
# (11, 1) Subaru_9.wav
# done!
# C:\Users\kienn\anaconda3\lib\site-packages\numpy\core\_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)

# %%
print(df)
# Out:
#              role      actor
# 0    hestia_1.wav     minase
# 1   hestia_10.wav     minase
# 2    hestia_2.wav     minase
# 3    hestia_3.wav     minase
# 4    hestia_4.wav     minase
# ..            ...        ...
# 93   Subaru_5.wav  kobayashi
# 94   Subaru_6.wav  kobayashi
# 95   Subaru_7.wav  kobayashi
# 96   Subaru_8.wav  kobayashi
# 97   Subaru_9.wav  kobayashi
#
# [98 rows x 2 columns]

# %% [markdown]
# # Data Preprocessing

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

oh = OneHotEncoder(sparse=False)
le = LabelEncoder()

to_train = le.fit_transform(y)

x_train, x_test, y_train ,y_test = train_test_split(trans_x,y,test_size=0.3,random_state=8)
x_train, x_test, y_train1 ,y_test1 = train_test_split(trans_x,to_train,test_size=0.3,random_state=8)


y_train2 = oh.fit_transform(np.array(y_train1).reshape(-1,1))
y_test2 = oh.fit_transform(np.array(y_test1).reshape(-1,1))


px_train, px_test, py_train ,py_test = train_test_split(trans_pca,y,test_size=0.3,random_state=8)

# %% [markdown]
# # Model Construction

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,recall_score,precision_score
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC 
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB as gb

def scoretest(clf,px_test,y_test):

    pred = clf.predict(px_test)
    acc = accuracy_score(y_test,pred)
    cm = confusion_matrix(y_test,pred)
    rec = recall_score(y_test,pred,average='macro')
    prec = precision_score(y_test,pred,average='macro')
    return acc,cm,rec,prec

def svm(x_train,y_train,x_test,y_test):

    parameters = {'kernel':('linear','poly','rbf'),'C':[0.1,1, 10, 100],'gamma':[1,0.1,0.01,0.001]}

    #print(kernel)
    svc =SVC(kernel='rbf',C=1,gamma=0.01)
    svc.fit(x_train,y_train)
    acc,cm,rec,prec = scoretest(clf,x_test,y_test)
    return acc,cm,rec,prec

def gaussian(x_train,y_train,x_test,y_test):
    clf = gb()
    
    clf.fit(x_train,y_train)

    print(clf.predict([x_test[0]]),y_test.iloc[0])
    acc,cm,rec,prec = scoretest(clf,x_test,y_test)
    return acc,cm,rec,prec

# %%
from sklearn.svm import SVC 
from sklearn.model_selection import GridSearchCV

parameters = {'kernel':('linear','poly','rbf'),'C':[0.1,1, 10, 100],'gamma':[1,0.1,0.01,0.001]}


svc=SVC()
clf = GridSearchCV(svc,parameters,verbose=3)
clf.fit(x_train,y_train)

# %%
res = pd.DataFrame(clf.cv_results_)
res = res[['param_C','param_gamma','param_kernel','mean_test_score','rank_test_score']]
res = res.sort_values(by=['rank_test_score'])
res = res.reset_index(drop=True)
res.groupby('param_kernel').first()

# %% [markdown]
# # Neural Network

# %%
import torch
from torch import nn
import torch.nn.functional as F

class NeuralNetwork(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(NeuralNetwork, self).__init__()
        self.layer1 = nn.Sequential(
            
            nn.Linear(input_size,hidden_size[0]),
#             nn.Conv1d(input_size,hidden_size,kernel_size=1),
            nn.ReLU()
#             nn.MaxPool1d(kernel_size=1)
        )
        self.layer2 = nn.Sequential(
#             nn.Conv1d(hidden_size,hidden_size2,kernel_size=3),
            nn.Linear(hidden_size[0],hidden_size[1]),
            nn.ReLU(),
#             nn.MaxPool1d(kernel_size=2)
        )
        self.layer3 = nn.Sequential(
            nn.Linear(hidden_size[1],hidden_size[2]),
            nn.ReLU(),
        )
        self.fc = nn.Linear(hidden_size[2],num_classes)
        
    def forward(self, x):
        x = self.layer1(x)
        x = self.layer2(x)
        x = self.layer3(x)
        x = x.reshape(x.size(0),-1)
        x = self.fc(x)
        x = F.softmax(x,dim=1)
        return x
    
def ann(x_test):
    pred = []
    name = []
    with torch.no_grad():
        for index,listing in enumerate(x_test):
            lists = torch.FloatTensor(listing).to(device)
            lists = lists.view(-1,x_test.shape[1])
            outputs = model(lists)
           # outputs = torch.Tensor.cpu(outputs).numpy()
            pred.append(torch.Tensor.cpu(torch.argmax(outputs)).numpy().item())
#             print(pred[-1])
#             name.append(le.inverse_transform([torch.Tensor.cpu(torch.argmax(outputs)).numpy().item()]))
#             print(name[-1])
            
        acc = accuracy_score(y_test1,pred)
        cm = confusion_matrix(y_test1,pred)
        rec = recall_score(y_test1,pred,average='macro')
        prec = precision_score(y_test1,pred,average='macro')
        return acc,cm,rec,prec

# %%
# Define Hyper-parameters 
input_size = x_train.shape[1]
hidden_size = [24,16,8,12,8]
num_classes = 4
num_epochs = 100
learning_rate = 0.0001

device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = NeuralNetwork(input_size, hidden_size, num_classes).to(device)
print(model)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)  
total_step = len(x_train)

for epoch in range(num_epochs):
    for index,listing in enumerate(x_train):
        # Forward pass
        lists = torch.FloatTensor(listing).to(device)
        lists = lists.view(-1,x_train.shape[1])
        #print(lists)
        outputs = model(lists)
        
        label = torch.FloatTensor([y_train2[index]]).to(device)
        label = label.view(-1,4)
#         outputs = outputs.view(1,-1)
#         print(outputs,label)
        
        loss = criterion(outputs, label)

        # Backprpagation and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

#         if (index+1) % 1000 == 0:
        print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
               .format(epoch+1, num_epochs, index+1, total_step, loss.item()))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18408/2082224273.py in <module>
#       1 # Define Hyper-parameters
# ----> 2 input_size = x_train.shape[1]
#       3 hidden_size = [24,16,8,12,8]
#       4 num_classes = 4
#       5 num_epochs = 100
#
# IndexError: tuple index out of range

# %%
x_train
# Out:
# array([array([-36.04365339,  22.44344318,  12.21548916,  24.96601019,
#                21.88255643,  23.66412501,  21.10438234,  12.2837384 ,
#                23.16662259,  23.7170689 , -36.04365339])             ,
#        array([-36.04365339,  22.76273765,  21.85814227,  21.67787471,
#                19.31464229,  20.45322053, -36.04365339])             ,
#        array([-36.04365339,  21.95040785,  14.19552954,  19.87024455,
#                21.07086581,  15.47120766,  15.49657232,  19.83769279,
#                21.60879455,  14.37252072, -36.04365339])             ,
#        array([-36.04365339,  22.31604577,  22.33187683,   9.9453995 ,
#                20.6370537 ,  10.22896101,  23.9955968 ,   9.45616764,
#                22.17373807, -36.04365339, -36.04365339])             ,
#        array([-36.04365339,  11.07249797,  15.58628025,  19.7922655 ,
#                11.63995647,  11.52094115,  17.18046421,  19.52706953,
#                19.9217431 ,  10.49156554, -36.04365339])             ,
#        array([  9.7178799 ,  20.14054745,  19.99793689,   9.9881603 ,
#                13.51016109,  19.42977947,  16.19902571,  20.95079488,
#                 9.4570152 ,   9.32891051, -36.04365339])             ,
#        array([ 18.31632919,  21.52802959,  20.77947357,  20.13250023,
#                19.83379966,  19.2399921 ,  19.45865148,  22.37508489,
#                20.42359062,  19.89905869, -36.04365339])             ,
#        array([ 11.6819961 ,  11.46378844,  11.2974667 ,  16.79957428,
#                10.75787306,  19.44436862,  10.63049461,  18.59256309,
#                19.82873796,  10.45914957, -36.04365339])             ,
#        array([22.16226619, 18.59738887, 20.5319698 , 19.36752147, 21.1567755 ,
#               18.72534981, 11.09020617, 19.90906821, 12.58440038, 19.00782724,
#               13.19063079])                                                   ,
#        array([ 15.86099369,  16.63239802,  21.04136828,  20.58999707,
#                20.64212249,  14.85624041,  20.86238016,  21.90557692,
#                20.17267714,  20.47239187, -36.04365339])             ,
#        array([ 16.4339612 ,  14.42660662,  21.61544465,  22.12174432,
#                21.85716531,  21.65984804,  22.39996165,  21.53210324,
#                21.40909815,  22.61713209, -36.04365339])             ,
#        array([-36.04365339,  19.27768537,  22.57656967,  19.60912603,
#                19.04115148,  20.90538978,  18.57480336,  11.34798961,
#                23.23644905,  20.1029571 , -36.04365339])             ,
#        array([ 20.58564671,  21.59932544,  15.03546282,  22.55292037,
#                21.11495967,  20.95384966,  21.26192037,  20.25310509,
#                21.17442408,  20.72288491, -36.04365339])             ,
#        array([-36.04365339,  20.16674059,  22.78232047,  20.84803706,
#                18.32684729,  19.42086307,  21.36201747,  19.75808855,
#                22.40260828,  20.80107054, -36.04365339])             ,
#        array([ 18.32482021,  20.22213402,  19.94906138,  20.61647479,
#                21.83192057,  18.87581237,  22.58583588,  15.3071457 ,
#                14.45518333,  16.17404726, -36.04365339])             ],
#       dtype=object)

# %% [markdown]
# # Main

# %%
acc,cm,rec,prec = [],[],[],[]

a,b,c,d = gaussian(x_train,y_train,x_test,y_test)
acc.append(a)
cm.append(b)
rec.append(c)
prec.append(d)

a,b,c,d = svm(x_train,y_train,x_test,y_test)
acc.append(a)
cm.append(b)
rec.append(c)
prec.append(d)

a,b,c,d = ann(x_test)
acc.append(a)
cm.append(b)
rec.append(c)
prec.append(d)

# %% [markdown]
# # Print Result

# %%
from prettytable import PrettyTable as pt
t=pt(['Methods','Accuracy','Recall','Precision','Confusion_Matrix'])

methods = ["Gaussian NB","SVM","Neural Network"]
for i,a,b,c,d in zip(methods,acc,rec,prec,cm):
    t.add_row([i,"{:.6f}".format(a),"{:.6f}".format(b),
           "{:.6f}".format(c),d])
t.align['Methods']='l'
print(t)
